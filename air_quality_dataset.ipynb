# %% [markdown]
# # Proyek Analisis Data: Air Quality Dataset
# * Nama: Grecilia Padmadewi Gosali
# * Email: grecilia.gosali@gmail.com
# * Id Dicoding: grecilia

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis
# * Stasiun mana yang memiliki tingkat pencemaran udara tertinggi berdasarkan konsentrasi PM2,5 dan PM10?
# * Apakah tingkat pencemaran udara memiliki kenaikan atau penurunan dari tahun 2013 hingga 2017?

# %% [markdown]
# ## Menyiapkan semua library yang dibutuhkan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# ##### Changping Station

# %%
changping_aq_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv")
changping_aq_df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
# 5   6  2013      3    1     5    3.0   3.0  10.0  17.0  400.0  71.0  -4.5
# 6   7  2013      3    1     6    4.0   6.0  12.0  22.0  500.0  65.0  -4.5
# 7   8  2013      3    1     7    3.0   6.0  25.0  39.0  600.0  48.0  -2.1
# 8   9  2013      3    1     8    9.0  25.0  13.0  42.0  700.0  46.0  -0.2
# 9  10  2013      3    1     9   11.0  29.0   5.0  18.0  500.0  73.0   0.6
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping
# 5  1022.6 -19.5   0.0  NNW   1.7  Changping
# 6  1023.4 -19.5   0.0  NNW   1.8  Changping
# 7  1024.6 -20.0   0.0   NW   2.5  Changping
# 8  1025.2 -20.5   0.0  NNW   2.8  Changping
# 9  1025.3 -20.4   0.0  NNW   3.8  Changping

# %% [markdown]
# ##### Dingling Station

# %%
dingling_aq_df = pd.read_csv('https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv')
dingling_aq_df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
# 5   6  2013      3    1     5    6.0   6.0  3.0  4.0  200.0  79.0  -4.5
# 6   7  2013      3    1     6    5.0  10.0  3.0  4.0  200.0  77.0  -4.5
# 7   8  2013      3    1     7    5.0   6.0  3.0  2.0  200.0  80.0  -2.1
# 8   9  2013      3    1     8    8.0   7.0  3.0  3.0  200.0  79.0  -0.2
# 9  10  2013      3    1     9    8.0   8.0  3.0  2.0  200.0  81.0   0.6
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling
# 5  1022.6 -19.5   0.0  NNW   1.7  Dingling
# 6  1023.4 -19.5   0.0  NNW   1.8  Dingling
# 7  1024.6 -20.0   0.0   NW   2.5  Dingling
# 8  1025.2 -20.5   0.0  NNW   2.8  Dingling
# 9  1025.3 -20.4   0.0  NNW   3.8  Dingling

# %% [markdown]
# ##### Dongsi Station

# %%
dongsi_aq_df = pd.read_csv('https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv')
dongsi_aq_df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0   3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0   3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0   NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0   5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0   7.0   NaN  200.0  84.0  -1.9
# 5   6  2013      3    1     5    4.0   4.0   9.0  25.0  300.0  78.0  -2.4
# 6   7  2013      3    1     6    5.0   5.0  10.0  29.0  400.0  67.0  -2.5
# 7   8  2013      3    1     7    3.0   6.0  12.0  40.0  400.0  52.0  -1.4
# 8   9  2013      3    1     8    3.0   6.0  12.0  41.0  500.0  54.0  -0.3
# 9  10  2013      3    1     9    3.0   6.0   9.0  31.0  400.0  69.0   0.4
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi
# 5  1027.5 -21.3   0.0   NW   2.4  Dongsi
# 6  1028.2 -20.4   0.0   NW   2.2  Dongsi
# 7  1029.5 -20.4   0.0  NNW   3.0  Dongsi
# 8  1030.4 -21.2   0.0   NW   4.6  Dongsi
# 9  1030.5 -23.3   0.0    N   5.5  Dongsi

# %% [markdown]
# ##### Shunyi Station

# %%
shunyi_aq_df = pd.read_csv('https://raw.githubusercontent.com/marceloreis/HTI/master/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv')
shunyi_aq_df.head(10)
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0   8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0   7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN   7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0   5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0   NaN  200.0  11.0  -2.4
# 5   6  2013      3    1     5   11.0  11.0  3.0   7.0  200.0  45.0  -2.8
# 6   7  2013      3    1     6   12.0  12.0  3.0   9.0  300.0  74.0  -4.0
# 7   8  2013      3    1     7   13.0  13.0  3.0  23.0  300.0  59.0  -2.4
# 8   9  2013      3    1     8    8.0   8.0  3.0  19.0  400.0  66.0  -1.0
# 9  10  2013      3    1     9    3.0   6.0  3.0  21.0  400.0  60.0   0.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1025.8 -20.5   0.0   NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0   NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0   NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0   NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0   NW   4.5  Shunyi
# 5  1028.2 -22.1   0.0  NNW   1.7  Shunyi
# 6  1029.0 -21.2   0.0  NNE   1.6  Shunyi
# 7  1030.5 -21.3   0.0   NE   1.7  Shunyi
# 8  1031.2 -21.8   0.0  NNW   2.7  Shunyi
# 9  1031.3 -22.9   0.0  SSW   0.8  Shunyi

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# ##### Changping Station

# %%
changping_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
changping_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("duplicates: ", changping_aq_df.duplicated().sum())
# Out:
# duplicates:  0

# %%
changping_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       72.326926     83.441738     20.975331     29.519796   1103.056282
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       46.000000     72.000000      7.000000     36.000000    800.000000
# 75%      100.000000    131.000000     18.000000     60.358200   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34460.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       54.316674     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       15.636600      3.400000    999.300000    -10.200000      0.000000
# 50%       46.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       80.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# ##### Dingling Station

# %%
dingling_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dingling_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print('duplicates: ', dingling_aq_df.duplicated().sum())
# Out:
# duplicates:  0

# %%
dingling_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# std       72.267723     79.541685     15.519259     26.383882    903.306220
# min        3.000000      2.000000      0.285600      1.026500    100.000000
# 25%       14.000000     26.000000      2.000000      9.000000    300.000000
# 50%       41.000000     60.000000      5.000000     19.000000    600.000000
# 75%       93.000000    117.000000     15.000000     38.000000   1200.000000
# max      881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33850.000000  35011.000000  35014.000000  35011.000000  35013.000000
# mean      68.548371     13.686111   1007.760278      1.505495      0.060366
# std       53.764424     11.365313     10.225664     13.822099      0.752899
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       31.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       61.000000     14.700000   1007.400000      1.800000      0.000000
# 75%       90.000000     23.300000   1016.000000     14.200000      0.000000
# max      500.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35021.000000
# mean       1.853836
# std        1.309808
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# ##### Dongsi Station

# %%
dongsi_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
dongsi_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
print('duplicates: ', dongsi_aq_df.duplicated().sum())
# Out:
# duplicates:  0

# %%
dongsi_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34314.000000  34511.000000  34401.000000  33463.000000  31867.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# std       86.575127     98.219860     22.905655     33.959230   1191.305887
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       22.000000     38.000000      4.000000     27.000000    600.000000
# 50%       61.000000     86.000000     10.000000     47.000000   1000.000000
# 75%      119.000000    151.000000     24.000000     73.000000   1700.000000
# max      737.000000    955.000000    300.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  34400.000000  35044.000000  35044.000000  35044.000000  35044.000000
# mean      57.210637     13.671490   1012.547419      2.447535      0.064020
# std       58.033275     11.458418     10.266059     13.810696      0.786282
# min        0.642600    -16.800000    987.100000    -35.300000      0.000000
# 25%       12.000000      3.100000   1004.000000     -8.800000      0.000000
# 50%       44.125200     14.600000   1012.200000      3.000000      0.000000
# 75%       81.000000     23.500000   1020.900000     15.000000      0.000000
# max     1071.000000     41.100000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35050.000000
# mean       1.860785
# std        1.280368
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# ##### Shunyi Station

# %%
shunyi_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
shunyi_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print('duplicates: ', shunyi_aq_df.duplicated().sum())
# Out:
# duplicates:  0

# %%
shunyi_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# std       81.231739     89.143718     19.572068     30.996828   1156.374102
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       19.000000     31.000000      2.000000     19.000000    400.000000
# 50%       55.000000     77.000000      5.000000     37.000000    800.000000
# 75%      112.000000    138.000000     17.000000     62.000000   1500.000000
# max      941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  33575.000000  35013.000000  35013.000000  35010.000000  35013.000000
# mean      55.201321     13.387969   1013.061938      2.465036      0.061094
# std       54.873726     11.483588     10.177339     13.726622      0.761668
# min        0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%       10.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%       43.000000     14.400000   1012.700000      3.100000      0.000000
# 75%       77.000000     23.200000   1021.000000     15.100000      0.000000
# max      351.716400     40.600000   1042.800000     27.500000     37.300000
#
#                WSPM
# count  35020.000000
# mean       1.807533
# std        1.287817
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       12.800000

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# ##### Changping Station

# %%
changping_aq_df[changping_aq_df['PM2.5'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10      SO2      NO2      CO  \
# 1308    1309  2013      4   24    12    NaN    NaN   9.0000  33.0000   400.0
# 1309    1310  2013      4   24    13    NaN  302.0   3.0000  16.0000   300.0
# 1814    1815  2013      5   15    14    NaN   70.0  46.0000  22.0000  1100.0
# 1815    1816  2013      5   15    15    NaN   71.0  39.0000  19.0000  1100.0
# 2417    2418  2013      6    9    17    NaN    NaN   5.9976  31.2056     NaN
# ...      ...   ...    ...  ...   ...    ...    ...      ...      ...     ...
# 34879  34880  2017      2   21     7    NaN    NaN      NaN      NaN     NaN
# 34880  34881  2017      2   21     8    NaN    NaN      NaN      NaN     NaN
# 34883  34884  2017      2   21    11    NaN    NaN      NaN      NaN     NaN
# 34885  34886  2017      2   21    13    NaN    NaN      NaN      NaN     NaN
# 34887  34888  2017      2   21    15    NaN    6.0      NaN  34.0000     NaN
#
#              O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 1308    72.0000  22.6   999.2  -7.3   0.0  NNW   5.7  Changping
# 1309    89.0000  23.4   998.7  -7.7   0.0  NNW   7.3  Changping
# 1814   157.0000  27.7  1005.8   2.0   0.0   SE   3.2  Changping
# 1815   188.0000  27.9  1005.2   4.2   0.0  SSE   1.6  Changping
# 2417    18.6354  17.8  1003.4  15.8   0.1  NNW   0.4  Changping
# ...         ...   ...     ...   ...   ...  ...   ...        ...
# 34879       NaN  -1.7  1023.1 -17.4   0.0    E   1.3  Changping
# 34880       NaN  -1.8  1023.8 -16.7   0.0    W   1.2  Changping
# 34883       NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9  Changping
# 34885       NaN  -1.0  1021.5  -9.4   0.0   SW   1.7  Changping
# 34887    2.0000  -2.1  1019.4  -5.3   0.0  ENE   2.0  Changping
#
# [774 rows x 18 columns]

# %%
changping_aq_pm25_mean = changping_aq_df['PM2.5'].mean()

changping_aq_df['PM2.5'].fillna(value=changping_aq_pm25_mean, inplace=True)

changping_aq_df['PM2.5'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['PM10'].isna()]
# Out:
#           No  year  month  day  hour      PM2.5  PM10     SO2      NO2     CO  \
# 1308    1309  2013      4   24    12  71.099743   NaN  9.0000  33.0000  400.0
# 2417    2418  2013      6    9    17  71.099743   NaN  5.9976  31.2056    NaN
# 2967    2968  2013      7    2    15  11.000000   NaN  3.7128  11.2915    NaN
# 3291    3292  2013      7   16     3  23.000000   NaN  3.0000  12.0000    NaN
# 3306    3307  2013      7   16    18   4.000000   NaN  3.0000  14.0000  300.0
# ...      ...   ...    ...  ...   ...        ...   ...     ...      ...    ...
# 34877  34878  2017      2   21     5  71.099743   NaN     NaN      NaN    NaN
# 34879  34880  2017      2   21     7  71.099743   NaN     NaN      NaN    NaN
# 34880  34881  2017      2   21     8  71.099743   NaN     NaN      NaN    NaN
# 34883  34884  2017      2   21    11  71.099743   NaN     NaN      NaN    NaN
# 34885  34886  2017      2   21    13  71.099743   NaN     NaN      NaN    NaN
#
#              O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 1308    72.0000  22.6   999.2  -7.3   0.0  NNW   5.7  Changping
# 2417    18.6354  17.8  1003.4  15.8   0.1  NNW   0.4  Changping
# 2967   113.7402  35.9   986.2  16.1   0.0  WSW   3.4  Changping
# 3291        NaN  22.5   988.2  19.7   0.0    N   1.0  Changping
# 3306    77.0000  31.9   993.2  15.8   0.0    N   0.7  Changping
# ...         ...   ...     ...   ...   ...  ...   ...        ...
# 34877       NaN  -3.0  1023.7 -18.2   0.0  NNE   0.7  Changping
# 34879       NaN  -1.7  1023.1 -17.4   0.0    E   1.3  Changping
# 34880       NaN  -1.8  1023.8 -16.7   0.0    W   1.2  Changping
# 34883       NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9  Changping
# 34885       NaN  -1.0  1021.5  -9.4   0.0   SW   1.7  Changping
#
# [582 rows x 18 columns]

# %%
changping_aq_df['PM10'].fillna(value=changping_aq_df['PM10'].mean(), inplace=True)

changping_aq_df['PM10'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['SO2'].isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10  SO2    NO2  \
# 26        27  2013      3    2     2   13.000000    9.000000  NaN   56.0
# 122      123  2013      3    6     2  146.000000  153.000000  NaN  100.0
# 1178    1179  2013      4   19     2   32.000000  164.000000  NaN   33.0
# 1274    1275  2013      4   23     2  155.000000  130.000000  NaN   49.0
# 1370    1371  2013      4   27     2   44.000000   74.000000  NaN   59.0
# ...      ...   ...    ...  ...   ...         ...         ...  ...    ...
# 34880  34881  2017      2   21     8   71.099743   94.657871  NaN    NaN
# 34883  34884  2017      2   21    11   71.099743   94.657871  NaN    NaN
# 34885  34886  2017      2   21    13   71.099743   94.657871  NaN    NaN
# 34887  34888  2017      2   21    15   71.099743    6.000000  NaN   34.0
# 35058  35059  2017      2   28    18   18.000000   57.000000  NaN    2.0
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 26      800.0  33.0  -1.7  1027.7 -17.4   0.0  SSW   1.5  Changping
# 122    2399.0  81.0   3.5  1004.8  -6.5   0.0    N   0.7  Changping
# 1178    600.0  44.0   7.4  1015.9  -2.1   0.0    E   2.4  Changping
# 1274    900.0  31.0  11.3  1002.4   6.4   0.0   SE   1.2  Changping
# 1370    700.0  43.0  13.0  1001.0  -1.7   0.0    E   0.2  Changping
# ...       ...   ...   ...     ...   ...   ...  ...   ...        ...
# 34880     NaN   NaN  -1.8  1023.8 -16.7   0.0    W   1.2  Changping
# 34883     NaN   NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9  Changping
# 34885     NaN   NaN  -1.0  1021.5  -9.4   0.0   SW   1.7  Changping
# 34887     NaN   2.0  -2.1  1019.4  -5.3   0.0  ENE   2.0  Changping
# 35058     NaN   2.0  13.4  1008.1 -13.6   0.0  WNW   3.0  Changping
#
# [628 rows x 18 columns]

# %%
changping_aq_df['SO2'].fillna(value=changping_aq_df['SO2'].mean(), inplace=True)

changping_aq_df['SO2'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['NO2'].isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  NO2  \
# 28        29  2013      3    2     4   14.000000   18.000000  24.000000  NaN
# 124      125  2013      3    6     4  149.000000  155.000000  59.000000  NaN
# 1057    1058  2013      4   14     1    8.000000   12.000000   3.000000  NaN
# 1061    1062  2013      4   14     5    4.000000    9.000000   3.000000  NaN
# 1180    1181  2013      4   19     4   42.000000   77.000000  19.000000  NaN
# ...      ...   ...    ...  ...   ...         ...         ...        ...  ...
# 34879  34880  2017      2   21     7   71.099743   94.657871  14.958906  NaN
# 34880  34881  2017      2   21     8   71.099743   94.657871  14.958906  NaN
# 34883  34884  2017      2   21    11   71.099743   94.657871  14.958906  NaN
# 34885  34886  2017      2   21    13   71.099743   94.657871  14.958906  NaN
# 34889  34890  2017      2   21    17   96.000000   96.000000   8.000000  NaN
#
#            CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 28      400.0  45.0  -3.4  1027.5 -17.0   0.0   NW   0.8  Changping
# 124    2500.0  81.0   2.4  1004.7  -6.2   0.0    N   1.0  Changping
# 1057    200.0  94.0   9.4  1004.6 -11.9   0.0  NNW   1.1  Changping
# 1061    200.0  92.0   6.7  1005.2 -16.0   0.0   NE   2.4  Changping
# 1180    800.0  38.0   6.9  1016.2  -3.1   0.0  ESE   2.5  Changping
# ...       ...   ...   ...     ...   ...   ...  ...   ...        ...
# 34879     NaN   NaN  -1.7  1023.1 -17.4   0.0    E   1.3  Changping
# 34880     NaN   NaN  -1.8  1023.8 -16.7   0.0    W   1.2  Changping
# 34883     NaN   NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9  Changping
# 34885     NaN   NaN  -1.0  1021.5  -9.4   0.0   SW   1.7  Changping
# 34889  1100.0   2.0  -2.1  1017.7  -4.0   0.3    E   1.9  Changping
#
# [667 rows x 18 columns]

# %%
changping_aq_df['NO2'].fillna(value=changping_aq_df['NO2'].mean(), inplace=True)

changping_aq_df['NO2'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['CO'].isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  \
# 27        28  2013      3    2     3   14.000000   24.000000  23.000000
# 123      124  2013      3    6     3  170.000000  179.000000  55.000000
# 178      179  2013      3    8    10  180.000000  257.000000  59.404800
# 219      220  2013      3   10     3    3.000000    7.000000   9.000000
# 315      316  2013      3   14     3   80.000000   88.000000  23.000000
# ...      ...   ...    ...  ...   ...         ...         ...        ...
# 34880  34881  2017      2   21     8   71.099743   94.657871  14.958906
# 34883  34884  2017      2   21    11   71.099743   94.657871  14.958906
# 34885  34886  2017      2   21    13   71.099743   94.657871  14.958906
# 34887  34888  2017      2   21    15   71.099743    6.000000  14.958906
# 35058  35059  2017      2   28    18   18.000000   57.000000  14.958906
#
#              NO2  CO    O3  TEMP    PRES  DEWP  RAIN   wd  WSPM    station
# 27     42.000000 NaN   NaN  -2.5  1027.7 -17.4   0.0   SW   1.7  Changping
# 123    74.000000 NaN  81.0   3.7  1004.7  -6.3   0.0    N   1.3  Changping
# 178    94.027400 NaN  65.0  17.3   997.3  -3.5   0.0   SE   1.4  Changping
# 219    24.000000 NaN  94.0   4.1  1018.1 -20.3   0.0   NW   2.5  Changping
# 315    69.000000 NaN  92.0   0.0  1021.0  -5.0   0.0    E   1.2  Changping
# ...          ...  ..   ...   ...     ...   ...   ...  ...   ...        ...
# 34880  44.182086 NaN   NaN  -1.8  1023.8 -16.7   0.0    W   1.2  Changping
# 34883  44.182086 NaN   NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9  Changping
# 34885  44.182086 NaN   NaN  -1.0  1021.5  -9.4   0.0   SW   1.7  Changping
# 34887  34.000000 NaN   2.0  -2.1  1019.4  -5.3   0.0  ENE   2.0  Changping
# 35058   2.000000 NaN   2.0  13.4  1008.1 -13.6   0.0  WNW   3.0  Changping
#
# [1521 rows x 18 columns]

# %%
changping_aq_df['CO'].fillna(value=changping_aq_df['CO'].mean(), inplace=True)

changping_aq_df['CO'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['O3'].isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  \
# 27        28  2013      3    2     3   14.000000   24.000000  23.000000
# 495      496  2013      3   21    15  138.000000  146.000000  27.000000
# 507      508  2013      3   22     3    3.000000    6.000000   3.000000
# 603      604  2013      3   26     3  144.000000  195.000000  14.000000
# 699      700  2013      3   30     3   70.000000   98.000000  61.000000
# ...      ...   ...    ...  ...   ...         ...         ...        ...
# 34880  34881  2017      2   21     8   71.099743   94.657871  14.958906
# 34883  34884  2017      2   21    11   71.099743   94.657871  14.958906
# 34885  34886  2017      2   21    13   71.099743   94.657871  14.958906
# 34888  34889  2017      2   21    16   78.000000   78.000000   3.000000
# 35059  35060  2017      2   28    19   28.000000   47.000000   4.000000
#
#              NO2           CO  O3  TEMP    PRES  DEWP  RAIN   wd  WSPM  \
# 27     42.000000  1152.301345 NaN  -2.5  1027.7 -17.4   0.0   SW   1.7
# 495    42.000000  1152.301345 NaN   6.7   996.8  -1.7   0.0   SE   0.9
# 507    14.000000  1152.301345 NaN   4.6  1007.3 -12.8   0.0  NNW   1.2
# 603    90.000000  1152.301345 NaN   0.1  1007.4  -5.1   0.0    N   0.1
# 699    63.000000  1152.301345 NaN   3.2  1013.8  -7.6   0.0   SE   1.7
# ...          ...          ...  ..   ...     ...   ...   ...  ...   ...
# 34880  44.182086  1152.301345 NaN  -1.8  1023.8 -16.7   0.0    W   1.2
# 34883  44.182086  1152.301345 NaN  -0.5  1022.7 -16.0   0.0  ESE   1.9
# 34885  44.182086  1152.301345 NaN  -1.0  1021.5  -9.4   0.0   SW   1.7
# 34888   2.000000   200.000000 NaN  -2.1  1018.4  -4.8   0.0   NE   1.9
# 35059  14.000000   300.000000 NaN  11.7  1008.9 -13.3   0.0  NNE   1.3
#
#          station
# 27     Changping
# 495    Changping
# 507    Changping
# 603    Changping
# 699    Changping
# ...          ...
# 34880  Changping
# 34883  Changping
# 34885  Changping
# 34888  Changping
# 35059  Changping
#
# [604 rows x 18 columns]

# %%
changping_aq_df['O3'].fillna(value=changping_aq_df['O3'].mean(), inplace=True)
changping_aq_df['O3'].isna().sum()

# %%
changping_aq_df[changping_aq_df['TEMP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      C
# 34086  34087  2017      1   19     6   91.0  115.0  24.0   81.0  2200.0
# 34087  34088  2017      1   19     7   80.0   91.0  12.0   82.0  1900.0
# 34088  34089  2017      1   19     8   73.0   80.0  13.0   73.0  1600.0
# 34282  34283  2017      1   27    10   19.0   29.0  23.0   36.0   900.0
# 34283  34284  2017      1   27    11   18.0   25.0  16.0   30.0   800.0
# 34284  34285  2017      1   27    12   20.0   20.0  13.0   26.0   700.0
# 34285  34286  2017      1   27    13   29.0   29.0  14.0   22.0   600.0
# 34286  34287  2017      1   27    14   29.0   40.0  12.0   20.0   600.0
#
#           O3  TEMP     PRES  DEWP  RAIN   wd  WSPM    station
# 16748    8.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16813   63.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16829   44.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16873   17.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16883    9.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16930   49.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 16933   56.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17007   77.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17030   69.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17052   20.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17053   18.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17078   17.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17090   51.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17112   79.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17150   53.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17261   71.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17263   57.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17266   66.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17267   71.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17311   28.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17322   12.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17340   16.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17342   18.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17348   75.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17354   63.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17364   59.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17381   30.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17398   31.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17412   43.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17436   71.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17486   50.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17516    2.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 17676   62.0   NaN      NaN   NaN   NaN   SE   1.6  Changping
# 31047  225.0   NaN      NaN   NaN   NaN   SE   1.7  Changping
# 31315   11.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 31316    4.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 31317   53.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 31318   74.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 31319   72.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 31320   79.0   NaN      NaN   NaN   NaN   SE   1.2  Changping
# 33872   38.0   NaN      NaN   NaN   NaN   NW   3.3  Changping
# 33882   37.0   NaN      NaN   NaN   NaN   NW   1.2  Changping
# 34083    2.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34084   42.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34085    2.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34086    3.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34087    2.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34088    4.0   NaN      NaN   NaN   NaN   NW   8.0  Changping
# 34282   39.0   NaN  1023.25   NaN   0.0   SE   1.4  Changping
# 34283   46.0   NaN  1023.00   NaN   0.0   SE   0.9  Changping
# 34284   54.0   NaN  1023.00   NaN   0.0   SE   0.7  Changping
# 34285   67.0   NaN      NaN   NaN   NaN  NaN   NaN  Changping
# 34286   72.0   NaN      NaN   NaN   NaN   SE   3.4  Changping

# %%
changping_aq_df['TEMP'].fillna(value=changping_aq_df['TEMP'].mean(), inplace=True)
changping_aq_df['TEMP'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['PRES'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 16748  16749  2015      1   27    20   35.0   44.0  34.0   58.0   900.0
# 16813  16814  2015      1   30    13   14.0   23.0  12.0   14.0   400.0
# 16829  16830  2015      1   31     5   10.0   14.0  21.0   21.0   600.0
# 16873  16874  2015      2    2     1   78.0   78.0  28.0   56.0  1300.0
# 16883  16884  2015      2    2    11  139.0  144.0  64.0   90.0  2700.0
# 16930  16931  2015      2    4    10   21.0   24.0  19.0   28.0   600.0
# 16933  16934  2015      2    4    13   15.0   30.0  30.0   20.0   500.0
# 17007  17008  2015      2    7    15    8.0   32.0   4.0   11.0   300.0
# 17030  17031  2015      2    8    14    8.0    8.0   8.0   10.0   200.0
# 17052  17053  2015      2    9    12   84.0   84.0  86.0   62.0  1500.0
# 17053  17054  2015      2    9    13  110.0  118.0  98.0   81.0  1700.0
# 17078  17079  2015      2   10    14   35.0   38.0  31.0   24.0   600.0
0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17090   51.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17112   79.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17150   53.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17261   71.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17263   57.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17266   66.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17267   71.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17311   28.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17322   12.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17340   16.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17342   18.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17348   75.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17354   63.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17364   59.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17381   30.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17398   31.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17412   43.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17436   71.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17486   50.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17516    2.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 17676   62.0  13.686111   NaN   NaN   NaN   SE   1.6  Changping
# 31047  225.0  13.686111   NaN   NaN   NaN   SE   1.7  Changping
# 31315   11.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 31316    4.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 31317   53.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 31318   74.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 31319   72.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 31320   79.0  13.686111   NaN   NaN   NaN   SE   1.2  Changping
# 33872   38.0  13.686111   NaN   NaN   NaN   NW   3.3  Changping
# 33882   37.0  13.686111   NaN   NaN   NaN   NW   1.2  Changping
# 34083    2.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34084   42.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34085    2.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34086    3.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34087    2.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34088    4.0  13.686111   NaN   NaN   NaN   NW   8.0  Changping
# 34285   67.0  13.686111   NaN   NaN   NaN  NaN   NaN  Changping
# 34286   72.0  13.686111   NaN   NaN   NaN   SE   3.4  Changping

# %%
changping_aq_df['PRES'].fillna(value=changping_aq_df['PRES'].mean(), inplace=True)
changping_aq_df['PRES'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['DEWP'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO  \
# 16748  16749  2015      1   27    20   35.0   44.0  34.0   58.0   900.0
# 16813  16814  2015      1   30    13   14.0   23.0  12.0   14.0   400.0
# 16829  16830  2015      1   31     5   10.0   14.0  21.0   21.0   600.0
# 16873  16874  2015      2    2     1   78.0   78.0  28.0   56.0  1300.0
# 16883  16884  2015      2    2    11  139.0  144.0  64.0   90.0  2700.0
# 16930  16931  2015      2    4    10   21.0   24.0  19.0   28.0   600.0
# 16933  16934  2015      2    4    13   15.0   30.0  30.0   20.0   500.0
# 17007  17008  2015      2    7    15    8.0   32.0   4.0   11.0   300.0
# 17030  17031  2015      2    8    14    8.0    8.0   8.0   10.0   200.0
# 17052  17053  2015      2    9    12   84.0   84.0  86.0   62.0  1500.0
# 17053  17054  2015      2    9    13  110.0  118.0  98.0   81.0  1700.0
# 17078  17079  2015      2   10    14   35.0   38.0  31.0   24.0   600.0
# 17090  17091  2015      2   11     2   19.0   36.0   7.0   20.0   600.0
# 17112  17113  2015      2   12     0   15.0   15.0   2.0    9.0   300.0
# 17150  17151  2015      2   13    14  109.0  109.0  50.0   60.0  1600.0
# 17261  17262  2015      2   18     5    8.0    8.0   2.0    5.0   300.0
# 17263  17264  2015      2   18     7   14.0   19.0  27.0   15.0   500.0
# 17266  17267  2015      2   18    10   15.0   15.0  34.0   12.0   600.0
# 17267  17268  2015      2   18    11   13.0   13.0  28.0   10.0   500.0
# 17311  17312  2015      2   20     7  118.0  118.0   5.0   28.0  1300.0
# 17322  17323  2015      2   20    18  143.0  143.0   5.0   42.0  1500.0
# 17340  17341  2015      2   21    12  170.0  170.0  10.0   38.0  2000.0
# 17342  17343  2015      2   21    14  203.0  203.0  10.0   42.0  2200.0
# 17348  17349  2015      2   21    20   30.0  547.0   2.0    7.0   300.0
# 17354  17355  2015      2   22     2  110.0  980.0   2.0    2.0   300.0
# 17364  17365  2015      2   22    12   27.0  139.0  14.0    8.0   400.0
# 31047  31048  2016      9   14    15  102.0  102.0   5.0   31.0  1400.0
# 31315  31316  2016      9   25    19  140.0  166.0   2.0  111.0  2100.0
# 31316  31317  2016      9   25    20  157.0  197.0   2.0  111.0  2300.0
# 31317  31318  2016      9   25    21  151.0  189.0   2.0   64.0  2200.0
# 31318  31319  2016      9   25    22  130.0  154.0   2.0   41.0  1800.0
# 31319  31320  2016      9   25    23  120.0  125.0   2.0   39.0  1600.0
# 31320  31321  2016      9   26     0   97.0   97.0   2.0   27.0  1200.0
# 33872  33873  2017      1   10     8    9.0   24.0   8.0   28.0   800.0
# 33882  33883  2017      1   10    18   14.0   31.0   6.0   27.0   500.0
# 34083  34084  2017      1   19     3   74.0   91.0  14.0   40.0  1200.0
# 34084  34085  2017      1   19     4  101.0  123.0   9.0   32.0   800.0
# 34085  34086  2017      1   19     5  105.0  126.0  14.0   76.0  1400.0
# 34086  34087  2017      1   19     6   91.0  115.0  24.0   81.0  2200.0
# 34087  34088  2017      1   19     7   80.0   91.0  12.0   82.0  1900.0
# 34088  34089  2017      1   19     8   73.0   80.0  13.0   73.0  1600.0
# 34285  34286  2017      1   27    13   29.0   29.0  14.0   22.0   600.0
# 34286  34287  2017      1   27    14   29.0   40.0  12.0   20.0   600.0
#
#           O3       TEMP         PRES      DEWP  RAIN   wd  WSPM    station
# 16748    8.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16813   63.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16829   44.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16873   17.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16883    9.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16930   49.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 16933   56.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17007   77.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17030   69.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17052   20.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17053   18.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17078   17.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17090   51.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17112   79.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17150   53.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17261   71.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17263   57.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17266   66.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17267   71.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17311   28.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17322   12.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17340   16.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17342   18.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17348   75.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17354   63.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17364   59.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17381   30.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17398   31.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17412   43.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17436   71.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17486   50.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17516    2.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 17676   62.0  13.686111  1007.760278  1.505495   NaN   SE   1.6  Changping
# 18158  105.0  18.300000  1009.200000  1.400000   NaN   NE   1.3  Changping
# 31047  225.0  13.686111  1007.760278  1.505495   NaN   SE   1.7  Changping
# 31315   11.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 31316    4.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 31317   53.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 31318   74.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 31319   72.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 31320   79.0  13.686111  1007.760278  1.505495   NaN   SE   1.2  Changping
# 33872   38.0  13.686111  1007.760278  1.505495   NaN   NW   3.3  Changping
# 33882   37.0  13.686111  1007.760278  1.505495   NaN   NW   1.2  Changping
# 34083    2.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34084   42.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34085    2.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34086    3.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34087    2.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34088    4.0  13.686111  1007.760278  1.505495   NaN   NW   8.0  Changping
# 34285   67.0  13.686111  1007.760278  1.505495   NaN  NaN   NaN  Changping
# 34286   72.0  13.686111  1007.760278  1.505495   NaN   SE   3.4  Changping

# %%
changping_aq_df['RAIN'].fillna(value=changping_aq_df['RAIN'].mean(), inplace=True)
changping_aq_df['RAIN'].isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['wd'].isna()]
# Out:
#           No  year  month  day  hour       PM2.5        PM10        SO2  \
# 5107    5108  2013      9   29    19  162.000000  166.000000  16.000000
# 5110    5111  2013      9   29    22  224.000000  177.000000   9.424800
# 5111    5112  2013      9   29    23  193.000000  177.000000   9.000000
# 6389    6390  2013     11   22     5   93.000000  103.000000  22.000000
# 6411    6412  2013     11   23     3  131.000000  137.000000  41.000000
# ...      ...   ...    ...  ...   ...         ...         ...        ...
# 34296  34297  2017      1   28     0  218.000000  311.000000  56.000000
# 34447  34448  2017      2    3     7   74.000000   79.000000  30.000000
# 34519  34520  2017      2    6     7   26.000000   62.000000  22.000000
# 34538  34539  2017      2    7     2   34.000000   34.000000  14.000000
# 34873  34874  2017      2   21     1   71.099743   94.657871  14.958906
#
#              NO2           CO         O3   TEMP    PRES  DEWP  RAIN   wd  \
# 5107   99.000000  1600.000000  10.000000  17.90  1010.5  15.7   0.0  NaN
# 5110   83.146500  1152.301345  10.281600  17.90  1011.0  15.5   0.0  NaN
# 5111   65.000000  1500.000000  13.000000  17.90  1010.8  15.3   0.0  NaN
# 6389   57.000000  3200.000000   3.641400  -1.60  1017.3  -6.7   0.0  NaN
# 6411   86.000000  3600.000000   3.000000   0.40  1012.1  -5.8   0.0  NaN
# ...          ...          ...        ...    ...     ...   ...   ...  ...
# 34296  54.000000  1500.000000  28.000000  -0.95  1015.5 -15.4   0.0  NaN
# 34447  76.000000  1800.000000   3.000000  -5.50  1016.1 -17.9   0.0  NaN
# 34519  78.000000  1000.000000   4.000000  -3.50  1022.0 -14.6   0.0  NaN
# 34538  34.000000   900.000000  24.000000  -2.20  1022.8 -16.3   0.0  NaN
# 34873  44.182086  1152.301345  57.940003  -3.00  1024.4 -19.0   0.0  NaN
#
#        WSPM    station
# 5107    0.0  Changping
# 5110    0.0  Changping
# 5111    0.0  Changping
# 6389    0.0  Changping
# 6411    0.0  Changping
# ...     ...        ...
# 34296   0.3  Changping
# 34447   0.2  Changping
# 34519   0.4  Changping
# 34538   0.1  Changping
# 34873   0.5  Changping
#
# [140 rows x 18 columns]

# %%
changping_aq_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %%
changping_aq_df.wd.fillna(value='NNW', inplace=True)
changping_aq_df.wd.isna().sum()
# Out:
# 0

# %%
changping_aq_df[changping_aq_df['WSPM'].isna()]
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2    NO2      CO    O3  \
# 16748  16749  2015      1   27    20   35.0   44.0  34.0   58.0   900.0   8.0
# 16813  16814  2015      1   30    13   14.0   23.0  12.0   14.0   400.0  63.0
# 16829  16830  2015      1   31     5   10.0   14.0  21.0   21.0   600.0  44.0
# 16873  16874  2015      2    2     1   78.0   78.0  28.0   56.0  1300.0  17.0
# 16883  16884  2015      2    2    11  139.0  144.0  64.0   90.0  2700.0   9.0
# 16930  16931  2015      2    4    10   21.0   24.0  19.0   28.0   600.0  49.0
# 16933  16934  2015      2    4    13   15.0   30.0  30.0   20.0   500.0  56.0
# 17007  17008  2015      2    7    15    8.0   32.0   4.0   11.0   300.0  77.0
# 17030  17031  2015      2    8    14    8.0    8.0   8.0   10.0   200.0  69.0
# 17052  17053  2015      2    9    12   84.0   84.0  86.0   62.0  1500.0  20.0
13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 31315  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 31316  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 31317  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 31318  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 31319  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34083  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34084  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34085  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34086  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34087  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping
# 34285  13.686111  1007.760278  1.505495  0.060366  NNW   NaN  Changping

# %%
changping_aq_df['WSPM'].fillna(value=changping_aq_df['WSPM'].mean(), inplace=True)
changping_aq_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
#check datatype
changping_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    35064 non-null  float64
#  6   PM10     35064 non-null  float64
#  7   SO2      35064 non-null  float64
#  8   NO2      35064 non-null  float64
#  9   CO       35064 non-null  float64
#  10  O3       35064 non-null  float64
#  11  TEMP     35064 non-null  float64
#  12  PRES     35064 non-null  float64
#  13  DEWP     35064 non-null  float64
#  14  RAIN     35064 non-null  float64
#  15  wd       35064 non-null  object
#  16  WSPM     35064 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# ##### Dingling Station

# %%
#Dingling Station memiliki missing values yang sama dengan Changping Station, sehingga dapat disimpulkan setiap untuk missing values digunakan metode imputation karena masih mengandung banyak informasi penting
dingling_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
dingling_aq_df['PM2.5'].fillna(value=dingling_aq_df['PM2.5'].mean(), inplace=True)
dingling_aq_df['PM10'].fillna(value=dingling_aq_df['PM10'].mean(), inplace=True)
dingling_aq_df['SO2'].fillna(value=dingling_aq_df['SO2'].mean(), inplace=True)
dingling_aq_df['NO2'].fillna(value=dingling_aq_df['NO2'].mean(), inplace=True)
dingling_aq_df['CO'].fillna(value=dingling_aq_df['CO'].mean(), inplace=True)
dingling_aq_df['O3'].fillna(value=dingling_aq_df['O3'].mean(), inplace=True)
dingling_aq_df['TEMP'].fillna(value=dingling_aq_df['TEMP'].mean(), inplace=True)
dingling_aq_df['PRES'].fillna(value=dingling_aq_df['PRES'].mean(), inplace=True)
dingling_aq_df['DEWP'].fillna(value=dingling_aq_df['DEWP'].mean(), inplace=True)
dingling_aq_df['RAIN'].fillna(value=dingling_aq_df['RAIN'].mean(), inplace=True)
dingling_aq_df['WSPM'].fillna(value=dingling_aq_df['WSPM'].mean(), inplace=True)
dingling_aq_df.wd.value_counts()
# Out:
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: wd, dtype: int64

# %%
dingling_aq_df.wd.fillna(value='NNW', inplace=True)
dingling_aq_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
#check datatype
dingling_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    35064 non-null  float64
#  6   PM10     35064 non-null  float64
#  7   SO2      35064 non-null  float64
#  8   NO2      35064 non-null  float64
#  9   CO       35064 non-null  float64
#  10  O3       35064 non-null  float64
#  11  TEMP     35064 non-null  float64
#  12  PRES     35064 non-null  float64
#  13  DEWP     35064 non-null  float64
#  14  RAIN     35064 non-null  float64
#  15  wd       35064 non-null  object
#  16  WSPM     35064 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# ##### Dongsi Station

# %%
#Dongsi Station memiliki missing values yang sama dengan Changping Station dan Dingling Station, sehingga dapat disimpulkan setiap untuk missing values digunakan metode imputation karena masih mengandung banyak informasi penting
dongsi_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       750
# PM10        553
# SO2         663
# NO2        1601
# CO         3197
# O3          664
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           78
# WSPM         14
# station       0
# dtype: int64

# %%
dongsi_aq_df['PM2.5'].fillna(value=dongsi_aq_df['PM2.5'].mean(), inplace=True)
dongsi_aq_df['PM10'].fillna(value=dongsi_aq_df['PM10'].mean(), inplace=True)
dongsi_aq_df['SO2'].fillna(value=dongsi_aq_df['SO2'].mean(), inplace=True)
dongsi_aq_df['NO2'].fillna(value=dongsi_aq_df['NO2'].mean(), inplace=True)
dongsi_aq_df['CO'].fillna(value=dongsi_aq_df['CO'].mean(), inplace=True)
dongsi_aq_df['O3'].fillna(value=dongsi_aq_df['O3'].mean(), inplace=True)
dongsi_aq_df['TEMP'].fillna(value=dongsi_aq_df['TEMP'].mean(), inplace=True)
dongsi_aq_df['PRES'].fillna(value=dongsi_aq_df['PRES'].mean(), inplace=True)
dongsi_aq_df['DEWP'].fillna(value=dongsi_aq_df['DEWP'].mean(), inplace=True)
dongsi_aq_df['RAIN'].fillna(value=dongsi_aq_df['RAIN'].mean(), inplace=True)
dongsi_aq_df['WSPM'].fillna(value=dongsi_aq_df['WSPM'].mean(), inplace=True)
dongsi_aq_df.wd.value_counts()
# Out:
# ENE    3861
# E      3564
# NE     3540
# ESE    2706
# SW     2481
# NW     2466
# SSW    1953
# NNE    1928
# SE     1880
# N      1865
# WSW    1769
# NNW    1693
# S      1547
# SSE    1402
# WNW    1347
# W       984
# Name: wd, dtype: int64

# %%
dongsi_aq_df.wd.fillna(value='ENE', inplace=True)
dongsi_aq_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
#check datatype
dongsi_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    35064 non-null  float64
#  6   PM10     35064 non-null  float64
#  7   SO2      35064 non-null  float64
#  8   NO2      35064 non-null  float64
#  9   CO       35064 non-null  float64
#  10  O3       35064 non-null  float64
#  11  TEMP     35064 non-null  float64
#  12  PRES     35064 non-null  float64
#  13  DEWP     35064 non-null  float64
#  14  RAIN     35064 non-null  float64
#  15  wd       35064 non-null  object
#  16  WSPM     35064 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# ##### Shunyi Station

# %%
#Shunyi Station memiliki missing values yang sama dengan Changping Station, Dingling Station, dan Dongsi Station, sehingga dapat disimpulkan setiap untuk missing values digunakan metode imputation karena masih mengandung banyak informasi penting
shunyi_aq_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
shunyi_aq_df['PM2.5'].fillna(value=shunyi_aq_df['PM2.5'].mean(), inplace=True)
shunyi_aq_df['PM10'].fillna(value=shunyi_aq_df['PM10'].mean(), inplace=True)
shunyi_aq_df['SO2'].fillna(value=shunyi_aq_df['SO2'].mean(), inplace=True)
shunyi_aq_df['NO2'].fillna(value=shunyi_aq_df['NO2'].mean(), inplace=True)
shunyi_aq_df['CO'].fillna(value=shunyi_aq_df['CO'].mean(), inplace=True)
shunyi_aq_df['O3'].fillna(value=shunyi_aq_df['O3'].mean(), inplace=True)
shunyi_aq_df['TEMP'].fillna(value=shunyi_aq_df['TEMP'].mean(), inplace=True)
shunyi_aq_df['PRES'].fillna(value=shunyi_aq_df['PRES'].mean(), inplace=True)
shunyi_aq_df['DEWP'].fillna(value=shunyi_aq_df['DEWP'].mean(), inplace=True)
shunyi_aq_df['RAIN'].fillna(value=shunyi_aq_df['RAIN'].mean(), inplace=True)
shunyi_aq_df['WSPM'].fillna(value=shunyi_aq_df['WSPM'].mean(), inplace=True)
shunyi_aq_df.wd.value_counts()
# Out:
# NNE    4540
# N      3877
# NE     3351
# SSE    2963
# SE     2665
# S      2613
# NW     2446
# WNW    2051
# NNW    1656
# SSW    1586
# ENE    1416
# ESE    1377
# W      1177
# E      1153
# SW      973
# WSW     737
# Name: wd, dtype: int64

# %%
shunyi_aq_df.wd.fillna(value='NNE', inplace=True)
shunyi_aq_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
#check datatype
shunyi_aq_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    35064 non-null  float64
#  6   PM10     35064 non-null  float64
#  7   SO2      35064 non-null  float64
#  8   NO2      35064 non-null  float64
#  9   CO       35064 non-null  float64
#  10  O3       35064 non-null  float64
#  11  TEMP     35064 non-null  float64
#  12  PRES     35064 non-null  float64
#  13  DEWP     35064 non-null  float64
#  14  RAIN     35064 non-null  float64
#  15  wd       35064 non-null  object
#  16  WSPM     35064 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Eksplorasi Data Pencemaran Udara Tertinggi dan Terendah berdasarkan PM2.5 dan PM10

# %% [markdown]
# ##### Changping Station

# %%
changping_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# std       71.524179     82.746329     20.786642     29.237672   1078.866266
# min        2.000000      2.000000      0.285600      1.847700    100.000000
# 25%       18.000000     34.000000      2.000000     22.000000    500.000000
# 50%       48.000000     74.000000      7.000000     37.000000    800.000000
# 75%       98.000000    129.000000     18.000000     60.000000   1400.000000
# max      882.000000    999.000000    310.000000    226.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      57.940003     13.686111   1007.760278      1.505495      0.060366
# std       53.846809     11.356720     10.218370     13.811648      0.752352
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       16.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       47.000000     14.600000   1007.400000      1.700000      0.000000
# 75%       79.000000     23.300000   1016.000000     14.200000      0.000000
# max      429.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35064.000000
# mean       1.853836
# std        1.309005
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# ##### Dingling Station

# %%
dingling_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# std       71.460423     78.794091     15.356856     25.915449    877.006409
# min        3.000000      2.000000      0.285600      1.026500    100.000000
# 25%       14.000000     26.000000      2.000000      9.000000    300.000000
# 50%       42.000000     62.000000      5.997600     20.000000    700.000000
# 75%       91.000000    116.000000     14.000000     37.000000   1100.000000
# max      881.000000    905.000000    156.000000    205.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      68.548371     13.686111   1007.760278      1.505495      0.060366
# std       52.825472     11.356720     10.218370     13.811648      0.752352
# min        0.214200    -16.600000    982.400000    -35.100000      0.000000
# 25%       32.000000      3.400000    999.300000    -10.200000      0.000000
# 50%       63.000000     14.600000   1007.400000      1.700000      0.000000
# 75%       89.000000     23.300000   1016.000000     14.200000      0.000000
# max      500.000000     41.400000   1036.500000     27.200000     52.100000
#
#                WSPM
# count  35064.000000
# mean       1.853836
# std        1.309005
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       10.000000

# %% [markdown]
# ##### Dongsi Station

# %%
dongsi_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      86.194297    110.336742     18.531107     53.699443   1330.069131
# std       85.644198     97.442239     22.688062     33.174871   1135.697130
# min        3.000000      2.000000      0.285600      2.000000    100.000000
# 25%       23.000000     38.000000      4.000000     28.000000    600.000000
# 50%       63.000000     88.000000     10.000000     49.000000   1100.000000
# 75%      117.000000    150.000000     24.000000     72.000000   1600.000000
# max      737.000000    955.000000    300.000000    258.000000  10000.000000
#
#                  O3         TEMP          PRES          DEWP          RAIN  \
# count  35064.000000  35064.00000  35064.000000  35064.000000  35064.000000
# mean      57.210637     13.67149   1012.547419      2.447535      0.064020
# std       57.481150     11.45515     10.263131     13.806757      0.786058
# min        0.642600    -16.80000    987.100000    -35.300000      0.000000
# 25%       13.000000      3.10000   1004.000000     -8.800000      0.000000
# 50%       46.000000     14.60000   1012.200000      3.000000      0.000000
# 75%       80.000000     23.50000   1020.900000     15.000000      0.000000
# max     1071.000000     41.10000   1042.000000     28.800000     46.400000
#
#                WSPM
# count  35064.000000
# mean       1.860785
# std        1.280113
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.400000
# max       10.500000

# %% [markdown]
# ##### Shunyi Station

# %%
shunyi_aq_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# std       80.167173     88.444361     19.206951     30.387486   1119.883237
# min        2.000000      2.000000      0.285600      2.000000    100.000000
# 25%       20.000000     32.000000      2.000000     20.000000    500.000000
# 50%       57.000000     79.000000      5.140800     39.000000    900.000000
# 75%      109.000000    137.000000     16.000000     61.000000   1500.000000
# max      941.000000    999.000000    239.000000    258.000000  10000.000000
#
#                  O3          TEMP          PRES          DEWP          RAIN  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      55.201321     13.387969   1013.061938      2.465036      0.061094
# std       53.695941     11.475233     10.169935     13.716048      0.761114
# min        0.214200    -16.800000    988.000000    -36.000000      0.000000
# 25%       11.000000      3.000000   1004.700000     -8.800000      0.000000
# 50%       47.000000     14.400000   1012.800000      3.000000      0.000000
# 75%       76.000000     23.200000   1021.000000     15.100000      0.000000
# max      351.716400     40.600000   1042.800000     27.500000     37.300000
#
#                WSPM
# count  35064.000000
# mean       1.807533
# std        1.287009
# min        0.000000
# 25%        1.000000
# 50%        1.500000
# 75%        2.300000
# max       12.800000

# %%
aq_mean_df = pd.DataFrame({
    'station_name': ['changping_station', 'dingling_station', 'dongsi_station', 'shunyi_station'],
    'PM2.5': [changping_aq_df['PM2.5'].mean(), dingling_aq_df['PM2.5'].mean(), dongsi_aq_df['PM2.5'].mean(), shunyi_aq_df['PM2.5'].mean()],
    'PM10': [changping_aq_df['PM10'].mean(), dingling_aq_df['PM10'].mean(), dongsi_aq_df['PM10'].mean(), shunyi_aq_df['PM10'].mean()]
})

aq_mean_df.head()
# Out:
#         station_name      PM2.5        PM10
# 0  changping_station  71.099743   94.657871
# 1   dingling_station  65.989497   83.739723
# 2     dongsi_station  86.194297  110.336742
# 3     shunyi_station  79.491602   98.737026

# %% [markdown]
# ### Eksplorasi Trend Data Pencemaran Udara

# %% [markdown]
# ##### Changping Station

# %%
changping_aq_trend_df = changping_aq_df.groupby(by='year').agg({
    'PM2.5': "mean",
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
})

changping_aq_trend_df.head()
# Out:
#           PM2.5        PM10        SO2        NO2           CO         O3
# year
# 2013  72.637567   91.257159  19.231476  41.251464  1052.052075  61.399195
# 2014  79.144216  106.318472  20.958338  45.557611  1195.430974  63.080795
# 2015  69.672148   94.153708  11.841341  42.799284  1161.859538  57.912187
# 2016  61.778503   86.422490   8.277616  45.548925  1123.589296  53.904720
# 2017  80.012286   94.364091  16.417615  50.947550  1524.400162  33.400410

# %% [markdown]
# ##### Dingling Station

# %%
dingling_aq_trend_df = dingling_aq_df.groupby(by='year').agg({
    'PM2.5': "mean",
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
})

dingling_aq_trend_df.head()
# Out:
#           PM2.5       PM10        SO2        NO2           CO         O3
# year
# 2013  64.777450  78.763031  14.032211  29.890448   852.777553  65.187935
# 2014  73.949575  90.358112  14.458873  27.362325   877.656411  72.515434
# 2015  64.627529  85.350134  11.351143  26.881813   966.453378  70.953036
# 2016  60.042212  80.514580   7.294931  25.486036   874.441321  67.357060
# 2017  68.350216  78.650888  13.250526  34.387971  1151.824317  53.948925

# %% [markdown]
# ##### Dongsi Station

# %%
dongsi_aq_trend_df = dongsi_aq_df.groupby(by='year').agg({
    'PM2.5': "mean",
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
})

dongsi_aq_trend_df.head()
# Out:
#            PM2.5        PM10        SO2        NO2           CO         O3
# year
# 2013   86.925760  105.018146  23.917829  57.598815  1335.308738  63.489913
# 2014   87.455485  116.939118  23.790487  55.582203  1367.693735  57.245953
# 2015   87.326436  111.840239  15.218665  50.372735  1335.668400  55.796035
# 2016   80.465800  103.282334  11.783750  51.196804  1243.028459  56.145993
# 2017  103.130529  131.536060  20.405056  57.933326  1575.439513  39.780815

# %% [markdown]
# ##### Shunyi Station

# %%
shunyi_aq_trend_df = shunyi_aq_df.groupby(by='year').agg({
    'PM2.5': "mean",
    'PM10': 'mean',
    'SO2': 'mean',
    'NO2': 'mean',
    'CO': 'mean',
    'O3': 'mean'
})

shunyi_aq_trend_df.head()
# Out:
#           PM2.5        PM10        SO2        NO2           CO         O3
# year
# 2013  77.280065   94.662433  15.611348  41.643163  1230.697973  56.589601
# 2014  84.472716  110.799902  17.380501  45.530298  1166.841285  58.348535
# 2015  81.250064   99.689977  10.540498  43.226413  1180.508108  52.165830
# 2016  72.051435   87.816802   9.874575  43.001996  1086.617368  56.021769
# 2017  95.421874  107.090435  21.125712  55.476500  1749.532339  42.220353

# %% [markdown]
# #### Merge Dataframes

# %%
merged_df1 = pd.merge(
    left=changping_aq_trend_df,
    right=dingling_aq_trend_df,
    how='left',
    left_on='year',
    right_on='year'
)

merged_df1.head()
# Out:
#         PM2.5_x      PM10_x      SO2_x      NO2_x         CO_x       O3_x  \
# year
# 2013  72.637567   91.257159  19.231476  41.251464  1052.052075  61.399195
# 2014  79.144216  106.318472  20.958338  45.557611  1195.430974  63.080795
# 2015  69.672148   94.153708  11.841341  42.799284  1161.859538  57.912187
# 2015  1335.668400  55.796035  81.250064   99.689977  10.540498  43.226413
# 2016  1243.028459  56.145993  72.051435   87.816802   9.874575  43.001996
# 2017  1575.439513  39.780815  95.421874  107.090435  21.125712  55.476500
#
#            CO_y_y     O3_y_y
# year
# 2013  1230.697973  56.589601
# 2014  1166.841285  58.348535
# 2015  1180.508108  52.165830
# 2016  1086.617368  56.021769
# 2017  1749.532339  42.220353
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Membuat Data Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi Pencemar

# %% [markdown]
# ##### PM2.5

# %%
pm25_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['PM2.5_x_x'],
    'Dingling Station': aq_trend_df['PM2.5_y_x'],
    'Dongsi Station': aq_trend_df['PM2.5_x_y'],
    'Shunyi Station': aq_trend_df['PM2.5_y_y']
})

pm25_trend_df.columns.name='Station'

pm25_trend_df.index.name='year'

print(pm25_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013             72.637567         64.777450       86.925760       77.280065
# 2014             79.144216         73.949575       87.455485       84.472716
# 2015             69.672148         64.627529       87.326436       81.250064
# 2016             61.778503         60.042212       80.465800       72.051435
# 2017             80.012286         68.350216      103.130529       95.421874

# %% [markdown]
# ##### PM10

# %%
pm10_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['PM10_x_x'],
    'Dingling Station': aq_trend_df['PM10_y_x'],
    'Dongsi Station': aq_trend_df['PM10_x_y'],
    'Shunyi Station': aq_trend_df['PM10_y_y']
})

pm10_trend_df.columns.name='Station'

pm10_trend_df.index.name='year'

print(pm10_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013             91.257159         78.763031      105.018146       94.662433
# 2014            106.318472         90.358112      116.939118      110.799902
# 2015             94.153708         85.350134      111.840239       99.689977
# 2016             86.422490         80.514580      103.282334       87.816802
# 2017             94.364091         78.650888      131.536060      107.090435

# %% [markdown]
# ##### SO2

# %%
so2_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['SO2_x_x'],
    'Dingling Station': aq_trend_df['SO2_y_x'],
    'Dongsi Station': aq_trend_df['SO2_x_y'],
    'Shunyi Station': aq_trend_df['SO2_y_y']
})

so2_trend_df.columns.name='Station'

so2_trend_df.index.name='year'

print(so2_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013             19.231476         14.032211       23.917829       15.611348
# 2014             20.958338         14.458873       23.790487       17.380501
# 2015             11.841341         11.351143       15.218665       10.540498
# 2016              8.277616          7.294931       11.783750        9.874575
# 2017             16.417615         13.250526       20.405056       21.125712

# %% [markdown]
# ##### NO2

# %%
no2_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['NO2_x_x'],
    'Dingling Station': aq_trend_df['NO2_y_x'],
    'Dongsi Station': aq_trend_df['NO2_x_y'],
    'Shunyi Station': aq_trend_df['NO2_y_y']
})

no2_trend_df.columns.name='Station'

no2_trend_df.index.name='year'

print(no2_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013             41.251464         29.890448       57.598815       41.643163
# 2014             45.557611         27.362325       55.582203       45.530298
# 2015             42.799284         26.881813       50.372735       43.226413
# 2016             45.548925         25.486036       51.196804       43.001996
# 2017             50.947550         34.387971       57.933326       55.476500

# %% [markdown]
# ##### CO

# %%
co_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['CO_x_x'],
    'Dingling Station': aq_trend_df['CO_y_x'],
    'Dongsi Station': aq_trend_df['CO_x_y'],
    'Shunyi Station': aq_trend_df['CO_y_y']
})

co_trend_df.columns.name='Station'

co_trend_df.index.name='year'

print(co_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013           1052.052075        852.777553     1335.308738     1230.697973
# 2014           1195.430974        877.656411     1367.693735     1166.841285
# 2015           1161.859538        966.453378     1335.668400     1180.508108
# 2016           1123.589296        874.441321     1243.028459     1086.617368
# 2017           1524.400162       1151.824317     1575.439513     1749.532339

# %% [markdown]
# ##### O3

# %%
o3_trend_df = pd.DataFrame({
    'Changping Station': aq_trend_df['O3_x_x'],
    'Dingling Station': aq_trend_df['O3_y_x'],
    'Dongsi Station': aq_trend_df['O3_x_y'],
    'Shunyi Station': aq_trend_df['O3_y_y']
})

o3_trend_df.columns.name='Station'

o3_trend_df.index.name='year'

print(o3_trend_df)
# Out:
# Station  Changping Station  Dingling Station  Dongsi Station  Shunyi Station
# year
# 2013             61.399195         65.187935       63.489913       56.589601
# 2014             63.080795         72.515434       57.245953       58.348535
# 2015             57.912187         70.953036       55.796035       52.165830
# 2016             53.904720         67.357060       56.145993       56.021769
# 2017             33.400410         53.948925       39.780815       42.220353

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Stasiun mana yang memiliki tingkat pencemaran udara tertinggi berdasarkan konsentrasi PM2,5 dan PM10?

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

colors = ['#B0C4DE', '#B0C4DE', '#00008B', '#B0C4DE']

sns.barplot(x='station_name', y='PM2.5', data=aq_mean_df, palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title(r"Berdasarkan Konsentrasi PM$_2$$_.$$_5$", loc='center', fontsize=15)
ax[0].tick_params(axis ='x', labelsize=12)

sns.barplot(x='station_name', y='PM10', data=aq_mean_df, palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title(r"Berdasarkan Konsentrasi PM$_1$$_0$", loc='center', fontsize=15)
ax[1].tick_params(axis ='x', labelsize=12)

plt.suptitle("Tingkat Pencemaran Udara Rata-Rata", fontsize=20)
plt.show()
# Out:
# <ipython-input-152-35a0d0f0c2a6>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='station_name', y='PM2.5', data=aq_mean_df, palette=colors, ax=ax[0])
# <ipython-input-152-35a0d0f0c2a6>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='station_name', y='PM10', data=aq_mean_df, palette=colors, ax=ax[1])

# %% [markdown]
# ### Apakah tingkat pencemaran udara memiliki kenaikan atau penurunan dari tahun 2013 hingga 2017?

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(pm25_trend_df.columns):
    color = cmap(i / len(pm25_trend_df.columns))
    plt.plot(pm25_trend_df.index, pm25_trend_df[column], color=color, label=column)
plt.title(r'Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi PM$_2$$_.$$_5$', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-153-13fa73d71afb>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(pm10_trend_df.columns):
    color = cmap(i / len(pm10_trend_df.columns))
    plt.plot(pm10_trend_df.index, pm10_trend_df[column], color=color, label=column)
plt.title(r'Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi PM$_1$$_0$', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-154-ebe1090645e9>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(so2_trend_df.columns):
    color = cmap(i / len(so2_trend_df.columns))
    plt.plot(so2_trend_df.index, so2_trend_df[column], color=color, label=column)
plt.title(r'Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi SO$_2$', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-155-f868bcd2fd7a>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(no2_trend_df.columns):
    color = cmap(i / len(no2_trend_df.columns))
    plt.plot(no2_trend_df.index, no2_trend_df[column], color=color, label=column)
plt.title(r'Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi NO$_2$', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-156-cd9338fe740b>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(co_trend_df.columns):
    color = cmap(i / len(co_trend_df.columns))
    plt.plot(co_trend_df.index, co_trend_df[column], color=color, label=column)
plt.title('Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi CO', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-157-d8ebf884ce76>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %%
plt.figure(figsize=(10 ,5))
cmap = plt.cm.get_cmap('viridis')

for i, column in enumerate(o3_trend_df.columns):
    color = cmap(i / len(o3_trend_df.columns))
    plt.plot(o3_trend_df.index, o3_trend_df[column], color=color, label=column)
plt.title(r'Trend Tingkat Pencemaran Udara Berdasarkan Konsentrasi O$_3$', loc='center', fontsize=20)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.legend()
plt.show()
# Out:
# <ipython-input-158-96e9b91567af>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('viridis')

# %% [markdown]
# ## KMeans Clustering

# %%
from sklearn.cluster import KMeans

features_for_clustering = ['PM2.5_x_x', 'PM10_x_x', 'O3_x_x', 'NO2_x_x', 'SO2_x_x', 'CO_x_x']

aq_trend_df.dropna(subset=features_for_clustering, inplace=True)

normalized_data = (aq_trend_df[features_for_clustering] - aq_trend_df[features_for_clustering].mean()) / aq_trend_df[features_for_clustering].std()

num_clusters = 4

# Performing KMeans clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
aq_trend_df['Cluster'] = kmeans.fit_predict(normalized_data)

# Visualizing the clusters
sns.pairplot(aq_trend_df, hue='Cluster', vars=features_for_clustering)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
aq_trend_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# ## Conclusion
# * Untuk pertanyaan 1, dapat disimpulkan bahwa Stasiun Dongsi memiliki tingkat pencemaran udara tertinggi.
# * Untuk pertanyaan 2, dapat disimpulkan dari data di atas bahwa tingkat pencemaran udara relatif meningkat dari tahun 2013 hingga 2017, walaupun konsentrasi O3 mengalami penurunan cukup drastis dari tahun 2013 hingga 2017.
